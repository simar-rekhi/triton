# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "*.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Copy of triton_kickoff.ipynb
# /content/drive/MyDrive/Colab Notebooks/ml_prac.ipynb
# /content/drive/MyDrive/Colab Notebooks/sklearn_practice.ipynb
# /content/drive/MyDrive/Colab Notebooks/day1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/triton_kickoff.ipynb

# %%
# !rm -f /content/triton

# %%
# !git clone https://github.com/simar-rekhi/triton.git
# %cd triton
# Out:
# Cloning into 'triton'...
# ...
# /content/triton

# %%
# !find /content -name "*.ipynb"
